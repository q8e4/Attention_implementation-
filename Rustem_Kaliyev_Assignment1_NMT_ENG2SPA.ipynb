# %% [markdown]
# In this assignment, we'll implement a sequence-to-sequence Transformer model for an English-to-Spanish machine translation task. The goals are as follow:
#
# - familiarize yourself with preparing text data and vectorizing text using the Keras TextVectorization layer.
# - Implement sinusoidal positional encoding using sine and cosine functions as presented in the lecture and original Transformer paper (i.e., 'Attention Is All You Need').
# - Implement multi-head attention machenism from scratch.
# - Run Transformer encoder and Transformer decoder to train the sequence-to-sequence model.
# - Use the trained model to generate translations from the input sentences
#
# Note that this assignment should be implemented using the Keras version 2.

# %%
import pathlib
import random
import string
import re
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow.data as tf_data
import tensorflow.strings as tf_strings

import keras
from keras import layers
from keras.layers import TextVectorization

# %% [markdown]
# # Preparing text data for machine translation

# %% [markdown]
# When constructing a neural machine translation (NMT) system, it's necessary to acquire data for both training and testing. Suppose we aim to develop an English-to-Spanish translator based on sentences. Numerous online resources are available for this purpose, such as user-generated content found in apps like Anki, specifically designed for language learning. Typically, this data is packaged within a ZIP file, encapsulating a SQLite database. From this repository, English-Spanish sentence pairs can be extracted for the translation model.

# %%
text_file = keras.utils.get_file(
    fname="spa-eng.zip",
    origin="http://storage.googleapis.com/download.tensorflow.org/data/spa-eng.zip",
    extract=True,
)
text_file = pathlib.Path(text_file).parent / "spa-eng" / "spa.txt"

# %% [markdown]
# Each line contains an English sentence and its corresponding Spanish sentence. The English sentence is the source sequence and Spanish one is the target sequence. We prepend the token "[start]" and we append the token "[end]" to the Spanish sentence.

# %%
with open(text_file) as f:
    lines = f.read().split("\n")[:-1]
text_pairs = []
for line in lines:
    eng, spa = line.split("\t")
    spa = "[start] " + spa + " [end]"
    text_pairs.append((eng, spa))

# %% [markdown]
# Here's what our sentence pairs look like:

# %%
for _ in range(5):
    print(random.choice(text_pairs))
# Out:
# ('We want it.', '[start] Lo queremos. [end]')
# ('I will only buy the car if they repair the brakes first.', '[start] Sólo compraré el coche si arreglan antes los frenos. [end]')
# ('I have my own way of solving it.', '[start] Tengo mi manera de resolverlo. [end]')
# ('She did the work carefully.', '[start] Ella hizo el trabajo con cuidado. [end]')
# ("I'm not being paid for this.", '[start] No me pagan por esto. [end]')

# %% [markdown]
# Now, let's split the sentence pairs into a training set, a validation set, and a test set.

# %%
random.shuffle(text_pairs)
num_val_samples = int(0.15 * len(text_pairs))
num_train_samples = len(text_pairs) - 2 * num_val_samples
train_pairs = text_pairs[:num_train_samples]
val_pairs = text_pairs[num_train_samples : num_train_samples + num_val_samples]
test_pairs = text_pairs[num_train_samples + num_val_samples :]

print(f"{len(text_pairs)} total pairs")
print(f"{len(train_pairs)} training pairs")
print(f"{len(val_pairs)} validation pairs")
print(f"{len(test_pairs)} test pairs")
# Out:
# 118964 total pairs
# 83276 training pairs
# 17844 validation pairs
# 17844 test pairs

# %% [markdown]
# # Vectorizing the text data
#
# We'll use two instances of the TextVectorization layer to vectorize the text data (one for English and one for Spanish), that is to say, to turn the original strings into integer sequences where each integer represents the index of a word in a vocabulary.
#
# The English layer will use the default string standardization (strip punctuation characters) and splitting scheme (split on whitespace), while the Spanish layer will use a custom standardization, where we add the character "¿" to the set of punctuation characters to be stripped.
#
# Note: in a production-grade machine translation model, I would not recommend stripping the punctuation characters in either language. Instead, I would recommend turning each punctuation character into its own token, which you could achieve by providing a custom split function to the TextVectorization layer.

# %%
strip_chars = string.punctuation + "¿"
strip_chars = strip_chars.replace("[", "")
strip_chars = strip_chars.replace("]", "")

vocab_size = 15000
sequence_length = 20
batch_size = 64


def custom_standardization(input_string):
    lowercase = tf_strings.lower(input_string)
    return tf_strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


eng_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
spa_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length + 1,
    standardize=custom_standardization,
)
train_eng_texts = [pair[0] for pair in train_pairs]
train_spa_texts = [pair[1] for pair in train_pairs]
eng_vectorization.adapt(train_eng_texts)
spa_vectorization.adapt(train_spa_texts)

# %% [markdown]
# Next, we'll format our datasets.
#
# At each training step, the model will seek to predict target words N+1 (and beyond) using the source sentence and the target words 0 to N.
#
# As such, the training dataset will yield a tuple (inputs, targets), where the input is a dict with keys `encoder_inputs` and `decoder_inputs`, each is a vector, corresponding to English and Spanish sentences respectively. The target is also vector of the Spanish sentence, advanced by 1 token. All vector are in the same length.
#
# The output will be used for training the transformer model. In the model we will create, the input tensors are named `encoder_inputs` and `decoder_inputs` which should be matched to the keys in the dictionary for the source part.

# %%
def format_dataset(eng, spa):
    eng = eng_vectorization(eng)
    spa = spa_vectorization(spa)
    return (
        {
            "encoder_inputs": eng,
            "decoder_inputs": spa[:, :-1],
        },
        spa[:, 1:],
    )


def make_dataset(pairs):
    eng_texts, spa_texts = zip(*pairs)
    eng_texts = list(eng_texts)
    spa_texts = list(spa_texts)
    dataset = tf_data.Dataset.from_tensor_slices((eng_texts, spa_texts))
    dataset = dataset.batch(batch_size)
    dataset = dataset.map(format_dataset)
    return dataset.cache().shuffle(2048).prefetch(16)


train_ds = make_dataset(train_pairs)
val_ds = make_dataset(val_pairs)

# %% [markdown]
# Let's take a quick look at the sequence shapes (we have batches of 64 pairs, and all sequences are 20 steps long). It means that We assumed that a sentence should have no more than 20 tokens.

# %%
for inputs, targets in train_ds.take(1):
    print(f'inputs["encoder_inputs"].shape: {inputs["encoder_inputs"].shape}')
    print(f'inputs["encoder_inputs"][0]: {inputs["encoder_inputs"][0]}')
    print(f'inputs["decoder_inputs"].shape: {inputs["decoder_inputs"].shape}')
    print(f'inputs["decoder_inputs"][0]: {inputs["decoder_inputs"][0]}')
    print(f"targets.shape: {targets.shape}")
    print(f"targets[0]: {targets[0]}")
# Out:
# inputs["encoder_inputs"].shape: (64, 20)
# inputs["encoder_inputs"][0]: [  33   71  497   19 1975    4  193  598    4  143    4 2418    0    0
#     0    0    0    0    0    0]
# inputs["decoder_inputs"].shape: (64, 20)
# inputs["decoder_inputs"][0]: [   2   37  939   11   10 1967    6  119   49 1434  521    5  387    6
#     9 3043    3    0    0    0]
# targets.shape: (64, 20)
# targets[0]: [  37  939   11   10 1967    6  119   49 1434  521    5  387    6    9
#  3043    3    0    0    0    0]

# %%
print(inputs["encoder_inputs"].shape)
# Out:
# (64, 20)

# %% [markdown]
# # **Task 1: Positional encoding**
#
# Upon vectorizing a sentence, we get a resulting vector of integers where each integer denoting a specific word. However, it's important to note that these integers merely serve as labels; proximity between two integers doesn't imply semantic relation between their corresponding words.
#
# To understand word meanings and establish relational measures between them, one employs word embeddings. But to understand the context, you also need to know the position of each word in a sentence. This is done by positional encoding.
#
# In this task, you need to implement sinusoidal positional encoding using sine and cosine functions as presented in the lecture. Specifically, in the original Transformer paper,the author used a sinusoidal function to get positional encoding which will append to encoder and decoder word embeddings. This is to give information about the position of each token. The function looks as follows:
#
#  $$\Large{PE_{(k, 2i)} = \sin(pos / 10000^{2i / d_{model}})} $$
# $$\Large{PE_{(k, 2i+1)} = \cos(pos / 10000^{2i / d_{model}})} $$
#
# Where, $k = 0, 1, .., L-1$ ($L$ is the length of input sequence), and $i=0, 1, .., d/2$.
#
# You can write your own position encoding layer, using model subclassing inherited from the base class ('layers.Layer') from Keras. Complete the code below with the basic structure of the custom layer class:

# %%
class SinusoidalPositionalEncoding(layers.Layer):
  def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
    super().__init__(**kwargs)

    self.sequence_length = sequence_length
    self.vocab_size = vocab_size
    self.embed_dim = embed_dim

    self.get_embeddings = layers.Embedding(input_dim=vocab_size, output_dim=embed_dim)

    pos_index = np.arange(self.sequence_length).reshape(self.sequence_length, 1)  # (sequence_length=20, 1)

    denom = np.power(10000, (2 * (np.arange(self.embed_dim) // 2)) / self.embed_dim)  # (embed_dim=,)
    angles = pos_index / denom

    angles[:, 0::2] = np.sin(angles[:, 0::2]) # even index xvalues
    angles[:, 1::2] = np.cos(angles[:, 1::2])

    self.positional_embeddings = tf.constant(angles, dtype=tf.float32)[None, :, :]  # (1, sequence_length, embed_dim)


  def call(self, inputs):

    embedding_vectors = self.get_embeddings(inputs)  # (batch_size, sequence_length, embed_dim)
    new_embeddings = embedding_vectors + self.positional_embeddings

    return new_embeddings

# %% [markdown]
# Here, input is the tokenized sentence (refer to an example of "encoder input" above). The positional embedding should return a tensor with shape $B×L×d_{model}$. You can add more subclasses or functions with suitable arguments if needed.

# %% [markdown]
# # **Task 2: Multi-head attention**
#
# Each multi-head attention block contains four steps:
#
# - Three linear (dense) layers that each receive the queries, keys, or values
# - Scaled dot-product attention operations performed h times in parallel, according to the number of heads composing the multi-head attention block.
# - Concatenate the outputs of the different heads
# - A final linear (dense) layer that produces the output
#
# In this task, you need to implement multi-head attention machenism from scratch. Specifically, you need to complete the code below for 'ScaledDotProductAttention' and 'MultiHeadAttentionCustom' classes, which inherit from the Layer base class in Keras:

# %%
class ScaledDotProductAttention(layers.Layer):
  def __init__(self):
    super().__init__()

  def call(self, query, key, value, mask=None):
    query_k = tf.matmul(query, key, transpose_b=True)  # QK^T
    dim = tf.cast(tf.shape(key)[-1], tf.float32)
    attention_logits = query_k / tf.math.sqrt(dim)
    attention_logits += (mask * -1e10) if mask is not None else 0  # applied mask also avoiding -inf value in softmax


    attention_w = tf.nn.softmax(attention_logits, axis=-1)
    output = tf.matmul(attention_w, value)

    return output, attention_w

class MultiHeadAttentionCustom(layers.Layer):
  def __init__(self, num_heads, key_dim):
    super().__init__()

    self.n_heads = num_heads
    self.key_dim = key_dim # overall dimension for key_dim * n_heads

    self.query_weights = layers.Dense(key_dim) # same dimensions for qkv
    self.value_weights = layers.Dense(key_dim)
    self.key_weights = layers.Dense(key_dim)

    self.attention = ScaledDotProductAttention()
    self.output_weights = layers.Dense(key_dim)



  def call(self, query, key, value, causal_mask=False):
    query = self.query_weights(query) # (batch_size, sequence_len, key_dim * n_heads)
    key = self.key_weights(key)
    value = self.value_weights(value)

    batch_size = tf.shape(query)[0]
    query = tf.reshape(query, (batch_size, -1, self.n_heads, self.key_dim // self.n_heads))
    key = tf.reshape(key, (batch_size, -1, self.n_heads, self.key_dim // self.n_heads))
    value = tf.reshape(value, (batch_size, -1, self.n_heads, self.key_dim // self.n_heads))

    query = tf.transpose(query, perm=[0, 2, 1, 3]) # (batch_size, n_heads, sequence_len, key_dim)
    key = tf.transpose(key, perm=[0, 2, 1, 3])
    value = tf.transpose(value, perm=[0, 2, 1, 3])

    # make a mask
    if causal_mask == True:
      # upper diagonal matrix, with 0 for valid positions and 1 for masked positions
      causal_mask = 1 - tf.linalg.band_part(tf.ones((tf.shape(query)[2], tf.shape(key)[2])), -1, 0)  # upper diagonal amtrix, (sequence_len, sequence_len)
      causal_mask = causal_mask[None, None, :, :]  # (1, 1, sequence_len, sequence_len) for broadcasting


    attention_output, attention_weights = self.attention(query, key, value, mask=causal_mask)

    attention_output = tf.transpose(attention_output, perm=[0, 2, 1, 3]) # (batch_size, sequence_len, n_heads, key_dim) for concat
    concatenated_attention = tf.reshape(attention_output, (batch_size, -1, self.key_dim) ) # merge heads back together
    output = self.output_weights(concatenated_attention)

    return output

# %% [markdown]
# You can add more subclasses or functions with suitable arguments if needed. Note that, for MultiHeadAttentionCustom, you should have a call argument ('causal_mask'), which is a boolean to indicate whether to apply a causal mask to prevent tokens from attending to future tokens (used in a decoder Transformer).

# %% [markdown]
# # Encoder and decoder
#
# The flowchart for the whole Transformer architecture is shown below, where the encoder is the block to the left, and decoder is the block to the right. Note that since the output shape of either encoder or decoder is the same as its corresponding input shape, both the encoder unit and the decoder unit can be stacked.
# ![Transformer Architecture](https://www.tensorflow.org/images/tutorials/transformer/transformer.png)
#
# We then present the transformer encoder architecture. Each encoder has a multihead self-attention (encoder-encoder) sublayer and a feedforward sublayer (two dense layers with ReLU activation in between). Each sublayer is followed by a LayerNorm taking the sublayer residually as follows:
#
# $$\Large{\mathit{LayerNorm}(x + \mathit{sublayer}(x))} $$

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = MultiHeadAttentionCustom(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(dense_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()


    def call(self, inputs, mask=None):

        attention_output = self.attention(
            query=inputs, value=inputs, key=inputs, causal_mask= False
        )
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "embed_dim": self.embed_dim,
                "dense_dim": self.dense_dim,
                "num_heads": self.num_heads,
            }
        )
        return config

# %% [markdown]
# The decoder follows a similar construction but with three sublayers instead of two: a multihead self-attention layer (decoder-decoder), a multihead encoder attention layer (decoder-encoder), and a feedforward layer similar to the one in an encoder unit.

# %%
class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = MultiHeadAttentionCustom(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = MultiHeadAttentionCustom(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [
                layers.Dense(latent_dim, activation="relu"),
                layers.Dense(embed_dim),
            ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, causal_mask= True
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            causal_mask= False,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_config(self):
        config = super().get_config()
        config.update(
            {
                "embed_dim": self.embed_dim,
                "latent_dim": self.latent_dim,
                "num_heads": self.num_heads,
            }
        )
        return config

# %% [markdown]
# # Assembling the Full Architecture
#
# Now we can build the full architecture of transformer using positional encoding, encoder layers and decoder layers:

# %%
embed_dim = 512
latent_dim = 64
num_heads = 8

encoder_inputs = keras.Input(shape=(None,), dtype="int64", name="encoder_inputs")
x = SinusoidalPositionalEncoding(sequence_length, vocab_size, embed_dim)(encoder_inputs)
encoder_outputs = TransformerEncoder(embed_dim, latent_dim, num_heads)(x)
encoder = keras.Model(encoder_inputs, encoder_outputs)

decoder_inputs = keras.Input(shape=(None,), dtype="int64", name="decoder_inputs")
encoded_seq_inputs = keras.Input(shape=(None, embed_dim), name="decoder_state_inputs")
x = SinusoidalPositionalEncoding(sequence_length, vocab_size, embed_dim)(decoder_inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
x = layers.Dropout(0.5)(x)
decoder_outputs = layers.Dense(vocab_size, activation="softmax")(x)
decoder = keras.Model([decoder_inputs, encoded_seq_inputs], decoder_outputs)

decoder_outputs = decoder([decoder_inputs, encoder_outputs])
transformer = keras.Model(
    [encoder_inputs, decoder_inputs], decoder_outputs, name="transformer"
)

# %% [markdown]
# # Train the machine translation model
#
# We'll use accuracy as a quick way to monitor training progress on the validation data. Note that machine translation typically uses BLEU scores as well as other metrics, rather than accuracy.
#
# Here we only train for 1 epoch, but to get the model to actually converge you should train for more epochs.

# %%
epochs = 120

transformer.summary()
transformer.compile(
    "rmsprop", loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
transformer.fit(train_ds, epochs=epochs, validation_data=val_ds)
# Out:
# Model: "transformer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ encoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sinusoidal_positio… │ (None, 20, 512)   │  7,680,000 │ encoder_inputs[0… │
# │ (SinusoidalPositio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_inputs      │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_encode… │ (None, 20, 512)   │  1,118,784 │ sinusoidal_posit… │
# │ (TransformerEncode… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional_7        │ (None, 20, 15000) │ 17,545,432 │ decoder_inputs[0… │
# │ (Functional)        │                   │            │ transformer_enco… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,344,216 (100.50 MB)
#  Trainable params: 26,344,216 (100.50 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 104s 71ms/step - accuracy: 0.6848 - loss: 2.3786 - val_accuracy: 0.7092 - val_loss: 1.9457
# Epoch 2/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 83s 64ms/step - accuracy: 0.7089 - loss: 1.9717 - val_accuracy: 0.7170 - val_loss: 1.7925
# Epoch 3/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7164 - loss: 1.8380 - val_accuracy: 0.7103 - val_loss: 1.7545
# Epoch 4/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7201 - loss: 1.7792 - val_accuracy: 0.7231 - val_loss: 1.6959
# Epoch 5/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7224 - loss: 1.7505 - val_accuracy: 0.7272 - val_loss: 1.6788
# Epoch 6/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7242 - loss: 1.7344 - val_accuracy: 0.7291 - val_loss: 1.6642
# Epoch 7/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7253 - loss: 1.7189 - val_accuracy: 0.7296 - val_loss: 1.6578
# Epoch 8/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7276 - loss: 1.7021 - val_accuracy: 0.7326 - val_loss: 1.6346
# Epoch 9/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.7316 - loss: 1.6725 - val_accuracy: 0.7333 - val_loss: 1.6350
# Epoch 10/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7332 - loss: 1.6559 - val_accuracy: 0.7371 - val_loss: 1.5945
# Epoch 11/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7341 - loss: 1.6449 - val_accuracy: 0.7348 - val_loss: 1.6038
# Epoch 12/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7352 - loss: 1.6382 - val_accuracy: 0.7370 - val_loss: 1.5862
# Epoch 13/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7375 - loss: 1.6250 - val_accuracy: 0.7480 - val_loss: 1.5253
# Epoch 14/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7483 - loss: 1.5558 - val_accuracy: 0.7565 - val_loss: 1.4646
# Epoch 15/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7552 - loss: 1.5083 - val_accuracy: 0.7664 - val_loss: 1.4139
# Epoch 16/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7649 - loss: 1.4435 - val_accuracy: 0.7706 - val_loss: 1.3789
# Epoch 17/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.7716 - loss: 1.3992 - val_accuracy: 0.7822 - val_loss: 1.3173
# Epoch 18/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7798 - loss: 1.3446 - val_accuracy: 0.7923 - val_loss: 1.2590
# Epoch 19/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.7874 - loss: 1.2884 - val_accuracy: 0.8004 - val_loss: 1.2049
# Epoch 20/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.7963 - loss: 1.2253 - val_accuracy: 0.8106 - val_loss: 1.1420
# Epoch 21/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 95s 73ms/step - accuracy: 0.8044 - loss: 1.1676 - val_accuracy: 0.8185 - val_loss: 1.0805
# Epoch 22/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.8132 - loss: 1.1069 - val_accuracy: 0.8246 - val_loss: 1.0320
# Epoch 23/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8195 - loss: 1.0600 - val_accuracy: 0.8316 - val_loss: 0.9891
# Epoch 24/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8264 - loss: 1.0158 - val_accuracy: 0.8392 - val_loss: 0.9478
# Epoch 25/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8322 - loss: 0.9771 - val_accuracy: 0.8421 - val_loss: 0.9355
# Epoch 26/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8360 - loss: 0.9490 - val_accuracy: 0.8434 - val_loss: 0.9108
# Epoch 27/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8404 - loss: 0.9179 - val_accuracy: 0.8464 - val_loss: 0.8963
# Epoch 28/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8442 - loss: 0.8938 - val_accuracy: 0.8516 - val_loss: 0.8668
# Epoch 29/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8464 - loss: 0.8792 - val_accuracy: 0.8519 - val_loss: 0.8611
# Epoch 30/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8493 - loss: 0.8610 - val_accuracy: 0.8556 - val_loss: 0.8473
# Epoch 31/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8521 - loss: 0.8437 - val_accuracy: 0.8559 - val_loss: 0.8421
# Epoch 32/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8542 - loss: 0.8303 - val_accuracy: 0.8581 - val_loss: 0.8264
# Epoch 33/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8555 - loss: 0.8235 - val_accuracy: 0.8578 - val_loss: 0.8321
# Epoch 34/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8577 - loss: 0.8067 - val_accuracy: 0.8616 - val_loss: 0.8120
# Epoch 35/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8585 - loss: 0.8016 - val_accuracy: 0.8608 - val_loss: 0.8116
# Epoch 36/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8603 - loss: 0.7884 - val_accuracy: 0.8623 - val_loss: 0.8014
# Epoch 37/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8619 - loss: 0.7800 - val_accuracy: 0.8617 - val_loss: 0.8050
# Epoch 38/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8635 - loss: 0.7715 - val_accuracy: 0.8631 - val_loss: 0.7995
# Epoch 39/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8646 - loss: 0.7649 - val_accuracy: 0.8655 - val_loss: 0.7884
# Epoch 40/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8659 - loss: 0.7569 - val_accuracy: 0.8657 - val_loss: 0.7873
# Epoch 41/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8673 - loss: 0.7500 - val_accuracy: 0.8660 - val_loss: 0.7882
# Epoch 42/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8684 - loss: 0.7417 - val_accuracy: 0.8620 - val_loss: 0.8039
# Epoch 43/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8698 - loss: 0.7353 - val_accuracy: 0.8682 - val_loss: 0.7850
# Epoch 44/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8702 - loss: 0.7325 - val_accuracy: 0.8680 - val_loss: 0.7779
# Epoch 45/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8718 - loss: 0.7216 - val_accuracy: 0.8680 - val_loss: 0.7779
# Epoch 46/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8721 - loss: 0.7215 - val_accuracy: 0.8660 - val_loss: 0.7815
# Epoch 47/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8727 - loss: 0.7205 - val_accuracy: 0.8706 - val_loss: 0.7691
# Epoch 48/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8744 - loss: 0.7093 - val_accuracy: 0.8705 - val_loss: 0.7672
# Epoch 49/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8758 - loss: 0.6991 - val_accuracy: 0.8718 - val_loss: 0.7626
# Epoch 50/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8756 - loss: 0.7029 - val_accuracy: 0.8706 - val_loss: 0.7673
# Epoch 51/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8773 - loss: 0.6911 - val_accuracy: 0.8702 - val_loss: 0.7664
# Epoch 52/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8775 - loss: 0.6897 - val_accuracy: 0.8717 - val_loss: 0.7747
# Epoch 53/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8789 - loss: 0.6828 - val_accuracy: 0.8716 - val_loss: 0.7707
# Epoch 54/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8796 - loss: 0.6779 - val_accuracy: 0.8731 - val_loss: 0.7623
# Epoch 55/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8802 - loss: 0.6715 - val_accuracy: 0.8745 - val_loss: 0.7609
# Epoch 56/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 94s 72ms/step - accuracy: 0.8812 - loss: 0.6682 - val_accuracy: 0.8721 - val_loss: 0.7682
# Epoch 57/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.8816 - loss: 0.6665 - val_accuracy: 0.8735 - val_loss: 0.7556
# Epoch 58/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.8822 - loss: 0.6624 - val_accuracy: 0.8717 - val_loss: 0.7783
# Epoch 59/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.8842 - loss: 0.6510 - val_accuracy: 0.8741 - val_loss: 0.7584
# Epoch 60/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8839 - loss: 0.6494 - val_accuracy: 0.8727 - val_loss: 0.7641
# Epoch 61/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8846 - loss: 0.6483 - val_accuracy: 0.8744 - val_loss: 0.7528
# Epoch 62/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8853 - loss: 0.6437 - val_accuracy: 0.8757 - val_loss: 0.7583
# Epoch 63/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8856 - loss: 0.6414 - val_accuracy: 0.8740 - val_loss: 0.7515
# Epoch 64/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8867 - loss: 0.6372 - val_accuracy: 0.8752 - val_loss: 0.7594
# Epoch 65/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8875 - loss: 0.6307 - val_accuracy: 0.8750 - val_loss: 0.7538
# Epoch 66/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8876 - loss: 0.6302 - val_accuracy: 0.8763 - val_loss: 0.7544
# Epoch 67/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8892 - loss: 0.6219 - val_accuracy: 0.8749 - val_loss: 0.7585
# Epoch 68/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8891 - loss: 0.6215 - val_accuracy: 0.8760 - val_loss: 0.7588
# Epoch 69/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8905 - loss: 0.6108 - val_accuracy: 0.8769 - val_loss: 0.7539
# Epoch 70/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8907 - loss: 0.6130 - val_accuracy: 0.8772 - val_loss: 0.7759
# Epoch 71/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8904 - loss: 0.6153 - val_accuracy: 0.8775 - val_loss: 0.7680
# Epoch 72/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8916 - loss: 0.6056 - val_accuracy: 0.8780 - val_loss: 0.7622
# Epoch 73/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8919 - loss: 0.6055 - val_accuracy: 0.8763 - val_loss: 0.7756
# Epoch 74/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8920 - loss: 0.6056 - val_accuracy: 0.8776 - val_loss: 0.7599
# Epoch 75/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8932 - loss: 0.5997 - val_accuracy: 0.8768 - val_loss: 0.7549
# Epoch 76/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8934 - loss: 0.5956 - val_accuracy: 0.8782 - val_loss: 0.7614
# Epoch 77/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8945 - loss: 0.5900 - val_accuracy: 0.8764 - val_loss: 0.7730
# Epoch 78/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8947 - loss: 0.5889 - val_accuracy: 0.8783 - val_loss: 0.7659
# Epoch 79/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8949 - loss: 0.5876 - val_accuracy: 0.8764 - val_loss: 0.7589
# Epoch 80/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8953 - loss: 0.5863 - val_accuracy: 0.8787 - val_loss: 0.7592
# Epoch 81/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8961 - loss: 0.5804 - val_accuracy: 0.8785 - val_loss: 0.7714
# Epoch 82/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8967 - loss: 0.5781 - val_accuracy: 0.8776 - val_loss: 0.7646
# Epoch 83/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8970 - loss: 0.5778 - val_accuracy: 0.8775 - val_loss: 0.7628
# Epoch 84/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.8977 - loss: 0.5717 - val_accuracy: 0.8770 - val_loss: 0.7562
# Epoch 85/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 94s 72ms/step - accuracy: 0.8980 - loss: 0.5699 - val_accuracy: 0.8765 - val_loss: 0.7635
# Epoch 86/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.8978 - loss: 0.5713 - val_accuracy: 0.8772 - val_loss: 0.7676
# Epoch 87/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8982 - loss: 0.5697 - val_accuracy: 0.8781 - val_loss: 0.7693
# Epoch 88/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.8991 - loss: 0.5628 - val_accuracy: 0.8760 - val_loss: 0.7740
# Epoch 89/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.8997 - loss: 0.5617 - val_accuracy: 0.8792 - val_loss: 0.7792
# Epoch 90/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 72ms/step - accuracy: 0.8994 - loss: 0.5612 - val_accuracy: 0.8786 - val_loss: 0.7654
# Epoch 91/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9006 - loss: 0.5559 - val_accuracy: 0.8786 - val_loss: 0.7762
# Epoch 92/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9007 - loss: 0.5551 - val_accuracy: 0.8784 - val_loss: 0.7753
# Epoch 93/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9006 - loss: 0.5550 - val_accuracy: 0.8791 - val_loss: 0.7670
# Epoch 94/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9020 - loss: 0.5483 - val_accuracy: 0.8777 - val_loss: 0.7775
# Epoch 95/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9020 - loss: 0.5469 - val_accuracy: 0.8785 - val_loss: 0.7791
# Epoch 96/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9022 - loss: 0.5458 - val_accuracy: 0.8792 - val_loss: 0.7850
# Epoch 97/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 143s 72ms/step - accuracy: 0.9026 - loss: 0.5442 - val_accuracy: 0.8793 - val_loss: 0.7916
# Epoch 98/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.9027 - loss: 0.5423 - val_accuracy: 0.8769 - val_loss: 0.7821
# Epoch 99/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.9040 - loss: 0.5366 - val_accuracy: 0.8793 - val_loss: 0.7850
# Epoch 100/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 143s 72ms/step - accuracy: 0.9033 - loss: 0.5395 - val_accuracy: 0.8788 - val_loss: 0.7830
# Epoch 101/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9043 - loss: 0.5348 - val_accuracy: 0.8788 - val_loss: 0.7787
# Epoch 102/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9040 - loss: 0.5354 - val_accuracy: 0.8794 - val_loss: 0.7929
# Epoch 103/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.9054 - loss: 0.5296 - val_accuracy: 0.8783 - val_loss: 0.7948
# Epoch 104/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9048 - loss: 0.5305 - val_accuracy: 0.8792 - val_loss: 0.7818
# Epoch 105/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.9053 - loss: 0.5298 - val_accuracy: 0.8771 - val_loss: 0.7845
# Epoch 106/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.9057 - loss: 0.5282 - val_accuracy: 0.8787 - val_loss: 0.7940
# Epoch 107/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.9059 - loss: 0.5257 - val_accuracy: 0.8785 - val_loss: 0.7844
# Epoch 108/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9062 - loss: 0.5234 - val_accuracy: 0.8800 - val_loss: 0.7847
# Epoch 109/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 136s 66ms/step - accuracy: 0.9069 - loss: 0.5209 - val_accuracy: 0.8788 - val_loss: 0.8151
# Epoch 110/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 90s 69ms/step - accuracy: 0.9066 - loss: 0.5226 - val_accuracy: 0.8805 - val_loss: 0.7939
# Epoch 111/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 91s 70ms/step - accuracy: 0.9070 - loss: 0.5202 - val_accuracy: 0.8795 - val_loss: 0.7934
# Epoch 112/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.9081 - loss: 0.5143 - val_accuracy: 0.8792 - val_loss: 0.7954
# Epoch 113/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.9077 - loss: 0.5158 - val_accuracy: 0.8801 - val_loss: 0.7982
# Epoch 114/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 91s 70ms/step - accuracy: 0.9078 - loss: 0.5148 - val_accuracy: 0.8799 - val_loss: 0.8080
# Epoch 115/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 91s 70ms/step - accuracy: 0.9085 - loss: 0.5114 - val_accuracy: 0.8804 - val_loss: 0.8005
# Epoch 116/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 70ms/step - accuracy: 0.9085 - loss: 0.5105 - val_accuracy: 0.8771 - val_loss: 0.8033
# Epoch 117/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 91s 70ms/step - accuracy: 0.9086 - loss: 0.5088 - val_accuracy: 0.8789 - val_loss: 0.7986
# Epoch 118/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9087 - loss: 0.5112 - val_accuracy: 0.8795 - val_loss: 0.8123
# Epoch 119/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 93s 71ms/step - accuracy: 0.9098 - loss: 0.5047 - val_accuracy: 0.8796 - val_loss: 0.7978
# Epoch 120/120
# 1302/1302 ━━━━━━━━━━━━━━━━━━━━ 92s 71ms/step - accuracy: 0.9094 - loss: 0.5060 - val_accuracy: 0.8800 - val_loss: 0.8112

# %% [markdown]
# # Translation testing
#
# Finally, let's demonstrate how to translate brand new English sentences. We simply feed into the model the vectorized English sentence as well as the target token "[start]", then we repeatedly generated the next token, until we hit the token "[end]".

# %%
spa_vocab = spa_vectorization.get_vocabulary()
spa_index_lookup = dict(zip(range(len(spa_vocab)), spa_vocab))
max_decoded_sentence_length = 20


def decode_sequence(input_sentence):
    tokenized_input_sentence = eng_vectorization([input_sentence])
    decoded_sentence = "[start]"
    for i in range(max_decoded_sentence_length):
        tokenized_target_sentence = spa_vectorization([decoded_sentence])[:, :-1]
        predictions = transformer([tokenized_input_sentence, tokenized_target_sentence])

        sampled_token_index = tf.math.argmax(predictions[0, i, :]).numpy().item(0)
        sampled_token = spa_index_lookup[sampled_token_index]
        decoded_sentence += " " + sampled_token

        if sampled_token == "[end]":
            break
    return decoded_sentence


test_eng_texts = [pair[0] for pair in test_pairs]
for _ in range(30):
    input_sentence = random.choice(test_eng_texts)
    translated = decode_sequence(input_sentence)

    print(input_sentence)
    print(translated)
# Out:
# He likes tea.
# [start] a él le gusta el té [end]
# The women of France are beautiful.
# [start] las mujeres [UNK] de francia son preciosa [end]
# Tom isn't the kind of person I want dating my daughter.
# [start] tom no es la clase de persona que quiero me quieras [end]
# The new president did what he thought was right.
# [start] el nuevo presidente lo que él lo tenía razón [end]
# The announcer called for attention.
# [start] el [UNK] cómo se llama atención [end]
# The mayor of this city was blamed for turning a deaf ear to the people's requests.
# [start] el alcalde de esta ciudad fue [UNK] a [UNK] un periodista de sordos [end]
# When I got up to go to school, the moon was still visible in the sky.
# [start] cuando no me levanté a la escuela para la escuela estaba todavía [UNK] en el cielo [end]
# I got up early this morning.
# [start] esta mañana me levanté pronto [end]
# Do you have a twin sister?
# [start] tienes una hermana gemela [end]
# He was fast asleep.
# [start] Él estaba dormidos [end]
# The doctor told me that I should eat less.
# [start] el doctor me dijo que debería comer menos [end]
# He went to a fruit store first.
# [start] Él fue a una fruta a una fruta [end]
# They claimed that Harrison could not read or write.
# [start] ellos [UNK] que no pudieron leer o escribir [end]
# A century is one hundred years.
# [start] un siglo cien horas [end]
# It's your duty to finish the job.
# [start] es tu deber terminar el trabajo [end]
# It rained all day yesterday.
# [start] ayer llovió todo el día [end]
# What is your greatest source of inspiration?
# [start] cuál es tu mejor parte de [UNK] [end]
# He said he wanted to be a scientist.
# [start] Él dijo que quería ser un científico [end]
# The workers were proud of their work.
# [start] los trabajadores estaban un poco de su trabajo [end]
# Children play with toys.
# [start] los niños juegan con niños [end]
# The firemen quickly extinguished the blaze.
# [start] los bomberos [UNK] rápidamente [end]
# Tell us more about what you did when you were in Boston.
# [start] [UNK] en boston de lo que hiciste en boston [end]
# I thought that's why Tom was here.
# [start] pensé que es por eso tom [end]
# You've probably done this many times before.
# [start] probablemente has hecho esto antes [end]
# Tom isn't babbling, is he?
# [start] tom no está murmurando [end]
# She was crying.
# [start] ella estaba llorando [end]
# This is all he has to do.
# [start] esto es todo lo que tiene que hacer [end]
# Tom wants some time to think about it.
# [start] tom quiere un poco de tiempo para pensarlo [end]
# I made my decision.
# [start] hice mi decisión [end]
# How can I make a long-distance call?
# [start] cómo puedo llamar una llamada [UNK] [end]

# %% [markdown]
# # Reference
# https://keras.io/examples/nlp/neural_machine_translation_with_transformer/
